# %% [markdown]
# #### Base

# %%
from pprint import pprint
import requests as req

loteria = 'megasena' # 'lotofacil'
url_base = f'https://loteriaeaqui.com.br/api/v1/{loteria}'
concurso = '2966'
url_concurso = f'{url_base}/{concurso}'

# %% [markdown]
# #### Importando dados

# %%
requisicao = req.get(url_base)
if requisicao.status_code == 200:
    dados = requisicao.json()
    pprint(dados)
# Out:
# {'concurso': 2985,
#  'dataProximoSorteio': '19/03/2026',
#  'dataSorteio': '17/03/2026',
#  'dezenasSorteadasOrdemCrescente': [6, 8, 21, 32, 41, 60],
#  'dezenasSorteadasOrdemSorteio': [32, 60, 21, 8, 6, 41],
#  'listaDeGanhadores': [{'ganhadores': 1,
#                         'municipio': 'CANAL ELETRONICO',
#                         'uf': '--'},
#                        {'ganhadores': 1, 'municipio': 'CATALAO', 'uf': 'GO'},
#                        {'ganhadores': 1,
#                         'municipio': 'PRESIDENTE CASTELO BRANCO',
#                         'uf': 'PR'}],
#  'listaDePremios': [{'acertos': '6 acertos',
#                      'numeroDeGanhadores': 3,
#                      'valor': 34856052.53},
#                     {'acertos': '5 acertos',
#                      'numeroDeGanhadores': 96,
#                      'valor': 34815.62},
#                     {'acertos': '4 acertos',
#                      'numeroDeGanhadores': 4494,
# ...
