# %%
import os

os.chdir(r'D:\Dev\Trabalho\Loterias\resultados')

# %%
import pandas as pd

df = pd.read_excel("megasena_resultados.xlsx")
md = df.to_markdown(index=False)

with open("megasena_resultados.md", "w", encoding="utf-8") as f:
    f.write(md)
